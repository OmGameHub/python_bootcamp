# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# load data set
data = pd.read_csv("experience_salary.csv")

# %%
X = data[["YearsExperience"]]
y = data[["Salary"]]

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
data["PredictedSalary"] = model.predict(X)

# %%
print("Model Coefficient (slope)", round(float(model.coef_[0]), 2))
print("Model Intercept (base salary)", round(float(model.intercept_), 2))
# Out:
# Model Coefficient (slope) 5806.58
# Model Intercept (base salary) 30956.39
# /var/folders/mm/r5bb4npd5xb0p1vm62_qp9pm0000gn/T/ipykernel_45417/2172202087.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Model Coefficient (slope)", round(float(model.coef_[0]), 2))
# /var/folders/mm/r5bb4npd5xb0p1vm62_qp9pm0000gn/T/ipykernel_45417/2172202087.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Model Intercept (base salary)", round(float(model.intercept_), 2))

# %%
plt.scatter(X, y, color="blue", label="Actual Salary")
plt.plot(X, data["PredictedSalary"], color="red", label="Predicted Salary")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Experience vs Salary")
plt.legend()
plt.show()
